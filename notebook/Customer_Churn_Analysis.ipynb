# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set_style("whitegrid")

# %% [markdown]
# # Customer Churn Analysis
#
# ## Step 2: Load Dataset
